# %%
import pandas as pd
import pyodbc
import sqlalchemy

# %%
df = pd.read_csv(r"C:\Users\tarun\Downloads\Power Bi Reports\SCM\Jan'24\part shipped.csv")
df.head()
# Out:
#     SL NO        SONO        CASEID     PART NUMBER  UNITPRICE  \
# 0  160021  BTTV956204    BTTV956204     7KW63-67001   25126.00
# 1  160025  8863454061  PO-128462314      M31750-001   20915.90
# 2  160029  BTVB699303    BTVB699303     4QD21-67005    3583.00
# 3  159328  8863508986  PO-128524924  RM2-6745-000CN    5474.28
# 4  159368  8863564417  PO-128592970      L46598-005    2722.44
#
#   DISPATCHDKTDATE  DISPATCHDKTNO    DEALERID  \
# 0      04-08-2023      D37760816  STRAC01942
# 1      04/20/2023            NaN  STRAC01998
# 2      02/14/2023      D27674439  STRAC01942
# 3      04/26/2023      X40467750  STRAC01999
# 4      05-03-2023  ACTIVE RETURN  STRAC01969
#
#                          PARTNER NAME         CITY  ...  ISACTIVE QUANTITY  \
# 0  SYSNET GLOBAL TECHNOLOGIES PVT LTD    SAMBALPUR  ...       YES        1
# 1   SYSNETGLOBAL TECHNOLOGIES PVT LTD    BANGALORE  ...        NO        1
# 2  SYSNET GLOBAL TECHNOLOGIES PVT LTD    SAMBALPUR  ...        NO        1
# ...

# %%
df.columns = df.columns.str.lower()
df.columns =df.columns.str.replace(" ","_")

# %%
df.drop(columns=['remarks'], inplace = True)
df.columns
# Out:
# Index(['sl_no', 'sono', 'caseid', 'part_number', 'unitprice',
#        'dispatchdktdate', 'dispatchdktno', 'dealerid', 'partner_name', 'city',
#        'delivery_challan_number', 'docket_date', 'docket_number', 'isactive',
#        'quantity', 'courier_name', 'destination', 'rmano', 'dcdate', 'type',
#        'consumptioncode', 'consumptiontype'],
#       dtype='object')

# %%
df['dcdate'] = pd.to_datetime(df['dcdate'], format='%d-%m-%Y')

# %%
# Create sql engine
username = 'sa'
password = 'sysneteod#1'
server = '10.20.30.55'
database = 'master'
engine =sqlalchemy.create_engine(f'mssql+pyodbc://{username}:{password}@10.20.30.55/master?trusted_connection=yes&driver=ODBC Driver 17 for SQL Server&Encrypt=No')
cnxn= engine.connect()

# %%
df.to_sql(name='docket_strac', con = cnxn, schema='dbo',if_exists= 'replace',index = False)
cnxn.close()

# %%
df.head()
# Out:
#     sl_no        sono        caseid     part_number  unitprice  \
# 0  160021  BTTV956204    BTTV956204     7KW63-67001   25126.00
# 1  160025  8863454061  PO-128462314      M31750-001   20915.90
# 2  160029  BTVB699303    BTVB699303     4QD21-67005    3583.00
# 3  159328  8863508986  PO-128524924  RM2-6745-000CN    5474.28
# 4  159368  8863564417  PO-128592970      L46598-005    2722.44
#
#   dispatchdktdate  dispatchdktno    dealerid  \
# 0      04-08-2023      D37760816  STRAC01942
# 1      04/20/2023            NaN  STRAC01998
# 2      02/14/2023      D27674439  STRAC01942
# 3      04/26/2023      X40467750  STRAC01999
# 4      05-03-2023  ACTIVE RETURN  STRAC01969
#
#                          partner_name         city  ...         docket_number  \
# 0  SYSNET GLOBAL TECHNOLOGIES PVT LTD    SAMBALPUR  ...             D59253865
# 1   SYSNETGLOBAL TECHNOLOGIES PVT LTD    BANGALORE  ...            9112330142
# ...

# %%
# Out:
# sl_no                               int64
# sono                               object
# caseid                             object
# part_number                        object
# unitprice                         float64
# dispatchdktdate                    object
# dispatchdktno                      object
# dealerid                           object
# partner_name                       object
# city                               object
# delivery_challan_number             int64
# docket_date                        object
# docket_number                      object
# isactive                           object
# quantity                            int64
# courier_name                       object
# destination                        object
# rmano                              object
# dcdate                     datetime64[ns]
# type                               object
# consumptioncode                    object
# consumptiontype                    object
# dtype: object
